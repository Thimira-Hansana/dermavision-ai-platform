# %% [markdown]
# # 02 Preprocessing
# Inspect CLAHE, resizing, and optional mask-assisted cropping.

# %%
from dermavision_ai.data.discovery import load_metadata
from dermavision_ai.data.preprocessing import PreprocessingConfig, preprocess_image

frame = load_metadata()
image = preprocess_image(frame.iloc[0]['image_path'], None, PreprocessingConfig())
image.shape
