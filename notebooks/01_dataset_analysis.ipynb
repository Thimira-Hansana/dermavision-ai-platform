# %% [markdown]
# # 01 Dataset Analysis
# Use this notebook to inspect HAM10000 metadata, class balance, demographics, and image distribution.

# %%
from dermavision_ai.data.discovery import load_metadata

frame = load_metadata()
frame.head()
