# %% [markdown]
# # 05 Hyperparameter Tuning
# Use Optuna to search over learning rate, dropout, batch size, and loss function.

# %%
import optuna

study = optuna.create_study(direction='maximize')
study
