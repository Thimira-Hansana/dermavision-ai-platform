# %% [markdown]
# # 06 Segmentation
# Inspect optional segmentation availability and experiment with lesion masks if present.

# %%
from dermavision_ai.segmentation.pipeline import describe_segmentation_status

describe_segmentation_status()
