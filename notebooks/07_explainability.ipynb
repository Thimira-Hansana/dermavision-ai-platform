# %% [markdown]
# # 07 Explainability
# Generate Grad-CAM overlays for qualitative model inspection.

# %%
from dermavision_ai.inference.service import InferenceService

service = InferenceService()
service.info()
