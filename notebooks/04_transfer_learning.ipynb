# %% [markdown]
# # 04 Transfer Learning
# Swap the configured backbone to compare pretrained models.

# %%
from dermavision_ai.training.engine import TrainerConfig

TrainerConfig(model_name='efficientnet_b0')
